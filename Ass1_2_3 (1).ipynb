# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/DSBDAL/assign_2/Assign_2_Dataset.csv")

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course math score  reading score  writing score
# 0                    none         72           72.0           74.0
# 1               completed         69           90.0           88.0
# ...

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     8
# reading score                  6
# writing score                  9
# dtype: int64

# %%
df.describe()
# Out:
#        reading score  writing score
# count     994.000000     991.000000
# mean       68.008048      69.487386
# std        16.602270      29.563757
# min         3.000000      10.000000
# 25%        58.000000      57.000000
# 50%        69.500000      69.000000
# 75%        79.000000      79.000000
# max       100.000000     567.000000

# %%
df.dtypes
# Out:
# gender                          object
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                      object
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.size
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   992 non-null    object
#  6   reading score                994 non-null    float64
#  7   writing score                991 non-null    float64
# dtypes: float64(2), object(6)
# memory usage: 62.6+ KB

# %%
# df["math score"] = df["math score"].astype('float')

# %%
encoded_df = pd.get_dummies(df, columns = ['gender'])
print(encoded_df)
# Out:
#     race/ethnicity parental level of education         lunch  \
# 0          group B           bachelor's degree      standard
# 1          group C                some college      standard
# 2          group B             master's degree      standard
# 3          group A          associate's degree  free/reduced
# 4          group C                some college      standard
# ..             ...                         ...           ...
# 995        group E             master's degree      standard
# 996        group C                 high school  free/reduced
# 997        group C                 high school  free/reduced
# 998        group D                some college      standard
# 999        group D                some college  free/reduced
#
#     test preparation course math score  reading score  writing score  \
# 0                      none         72           72.0           74.0
# 1                 completed         69           90.0           88.0
# ...

# %%
df['gender'].replace({'female' : 0 , 'male' : 1, 'other' : 2}, inplace=True)

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0       0        group B           bachelor's degree      standard
# 1       0        group C                some college      standard
# 2       0        group B             master's degree      standard
# 3       1        group A          associate's degree  free/reduced
# 4       1        group C                some college      standard
# 5       0        group B          associate's degree      standard
# 6       0        group B                some college      standard
# 7       1        group B                some college  free/reduced
# 8       1        group D                 high school  free/reduced
# 9       0        group B                 high school  free/reduced
#
#   test preparation course math score  reading score  writing score
# 0                    none         72           72.0           74.0
# 1               completed         69           90.0           88.0
# ...

# %%
# ass2
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     8
# reading score                  6
# writing score                  9
# dtype: int64

# %%
null_rows = df[df.isnull().any(axis=1)]
# null_rows = df[df['math score']=='?']
print(null_rows)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 17        0        group B            some high school  free/reduced
# 18        1        group C             master's degree  free/reduced
# 19        0        group C          associate's degree  free/reduced
# 20        1        group D                 high school      standard
# 21        0        group B                some college  free/reduced
# 22        1        group D                some college      standard
# 23        0        group C            some high school      standard
# 28        1        group C                 high school      standard
# 34        1        group E                some college      standard
# 38        0        group D          associate's degree  free/reduced
# 691       0        group E          associate's degree  free/reduced
# 692       0        group C           bachelor's degree  free/reduced
# 693       0        group D          associate's degree      standard
# ...

# %%
reading_mean = df['reading score'].mean()
df['reading score'] = df['reading score'].fillna(reading_mean)

# %%
reading_mean = df['writing score'].median()
df['writing score'] = df['writing score'].fillna(reading_mean)

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     8
# reading score                  0
# writing score                  0
# dtype: int64

# %%
null_rows = df[df['math score']=='?']
print(null_rows)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 432       1        group C                 high school      standard
# 433       0        group A            some high school  free/reduced
# 434       1        group C            some high school      standard
# 435       1        group C                some college  free/reduced
# 436       1        group D          associate's degree      standard
# 437       1        group D          associate's degree  free/reduced
# 438       1        group C                 high school      standard
# 439       1        group D            some high school      standard
# 440       0        group C                some college      standard
# 441       0        group D                 high school      standard
# 442       0        group A            some high school  free/reduced
# 443       0        group B          associate's degree      standard
# 444       1        group A            some high school  free/reduced
# ...

# %%
# Convert '?' to NaN
df['math score'] = pd.to_numeric(df['math score'],errors = "coerce")

# Calculate mean of 'math score' excluding NaN values
mean_score = df['math score'].mean()

# Replace NaN values with the mean
df['math score'].fillna(mean_score, inplace=True)

df.dtypes
# Out:
# gender                           int64
# race/ethnicity                  object
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                     float64
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
Q1 = df['reading score'].quantile(0.25)
Q3 = df['reading score'].quantile(0.75)
IQR = Q3-Q1

threshold = 1.5
outliers = df[(df['reading score']< (Q1-threshold*IQR))|(df['reading score'] > (Q3+threshold*IQR))]
outliers_cnt = len(outliers)
print("Total number of Outliers : ", outliers_cnt)
# Out:
# Total number of Outliers :  24

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
import seaborn as sb
sb.histplot(df['math score'])
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
# ass3
dfIris = pd.read_csv('/content/drive/MyDrive/DSBDAL/assign_3/Iris.csv')
# dfIris.head()
dfIris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0         0        group B           bachelor's degree      standard
# 1         0        group C                some college      standard
# 2         0        group B             master's degree      standard
# 3         1        group A          associate's degree  free/reduced
# 4         1        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995       0        group E             master's degree      standard
# 996       1        group C                 high school  free/reduced
# 997       0        group C                 high school  free/reduced
# 998       0        group D                some college      standard
# 999       0        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
Summary_stats = df.groupby('gender')['math score'].describe()
Summary_stats
# Out:
#         count       mean        std   min   25%   50%   75%    max
# gender
# 0       518.0  64.038909  20.675901 -89.0  54.0  65.0  74.0  334.0
# 1       482.0  68.779615  13.892553  27.0  60.0  68.0  79.0  100.0

# %%
dfIris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
setosa = dfIris[dfIris['Species']=="Iris-setosa"]
# dfIris.dtypes

# %%
def Calculate_Mean(dataframe):
    means = {}
    for column in dataframe.columns:
        type = dfIris[column].dtype
        if(type == 'int64' or type == 'float64'):
            column_values = dataframe[column].values
            means[column] = sum(column_values) / len(column_values)
    return means
Calculate_Mean(setosa)
# Out:
# {'Id': 25.5,
#  'SepalLengthCm': 5.005999999999999,
#  'SepalWidthCm': 3.4180000000000006,
#  'PetalLengthCm': 1.464,
#  'PetalWidthCm': 0.2439999999999999}

# %%
def calculate_median(dataframe):
    medians = {}
    for column in dataframe.columns:
        type = dfIris[column].dtype
        if(type == 'int64' or type == 'float64'):
            column_values = dataframe[column].values
            sorted_values = sorted(column_values)
            length = len(sorted_values)
            if length % 2 == 0:
                median = (sorted_values[length // 2 - 1] + sorted_values[length // 2]) / 2
            else:
                median = sorted_values[length // 2]
            medians[column] = median
    return medians

calculate_median(setosa)
# Out:
# {'Id': 25.5,
#  'SepalLengthCm': 5.0,
#  'SepalWidthCm': 3.4,
#  'PetalLengthCm': 1.5,
#  'PetalWidthCm': 0.2}

# %%
def calculate_standard_deviation(dataframe):
    standard_deviations = {}
    for column in dataframe.columns:
        type = dfIris[column].dtype
        if(type == 'int64' or type == 'float64'):
            column_values = dataframe[column].values
            mean = sum(column_values) / len(column_values)
            squared_diff_sum = sum((x - mean) ** 2 for x in column_values)
            variance = squared_diff_sum / len(column_values)
            standard_deviations[column] = np.sqrt(variance)
    return standard_deviations

calculate_standard_deviation(setosa)
# Out:
# {'Id': 14.430869689661812,
#  'SepalLengthCm': 0.348946987377739,
#  'SepalWidthCm': 0.37719490982779713,
#  'PetalLengthCm': 0.17176728442867115,
#  'PetalWidthCm': 0.10613199329137278}

# %%
def calculate_variance(dataframe):
    variances = {}
    for column in dataframe.columns:
        type = dfIris[column].dtype
        if(type == 'int64' or type == 'float64'):
            column_values = dataframe[column].values
            mean = sum(column_values) / len(column_values)
            squared_diff_sum = sum((x - mean) ** 2 for x in column_values)
            variances[column] = squared_diff_sum / len(column_values)
    return variances

calculate_variance(setosa)
# Out:
# {'Id': 208.25,
#  'SepalLengthCm': 0.12176399999999993,
#  'SepalWidthCm': 0.142276,
#  'PetalLengthCm': 0.02950400000000001,
#  'PetalWidthCm': 0.011263999999999996}

# %%
def caluculate_mode(column):
    freq = {}
    print("colum " , column)
    for value in column.values:
        if(value in freq):
            freq[value]+=1
        else:
            freq[value]=1

    mode_values = []
    max_value = 0
    for key,value in freq.items():
        if(value>max_value):
            max_value = value
            mode_values = [key]
        elif(value==max_value):
            mode_values.append(key)

    return mode_values
calculate_mode(dfIris['SepalWidthCm'])
# Out:
# [3.0]

# %%
dfIris['SepalWidthCm'].mode()
# Out:
# 0    3.0
# Name: SepalWidthCm, dtype: float64
